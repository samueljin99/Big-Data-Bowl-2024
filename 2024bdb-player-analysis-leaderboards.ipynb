# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
pd.set_option('display.max_columns', None)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/bdb2024-force-data/Force_Data_1_8.parquet
# /kaggle/input/force-data-1-8-all/Force_Data_1_8_total.parquet

# %%
def overall_tackler_stats(D):
    D['num_tackles'] = D.drop_duplicates(['gameId','playId','nflId']).query('(tackle == 1) | (assist == 1)').shape[0]
    D['total_plays'] = D.drop_duplicates(['gameId','playId','nflId']).shape[0]
    D['overal_tackle_pct'] = D.num_tackles / D.total_plays
    return D.drop(columns=['nflId'])

# %%
force_data = pd.read_parquet('/kaggle/input/force-data-1-8-all/Force_Data_1_8_total.parquet')

# %%
force_data.columns[60:90]
# Out:
# Index(['pff_missedTackle', 'birthDate', 'collegeName', 'position',
#        'last_frame', 'ToLeft', 'onOffense', 'absoluteYardlineNumber_std',
#        'X_std', 'Y_std', 'o_deg', 'o_deg_std', 'o_rad', 'o_rad_std', 'dir_deg',
#        'dir_deg_std', 'dir_rad', 'dir_rad_std', 'MPH', 'end_distance',
#        'speed_x', 'speed_y', 'a_x', 'a_y', 'a_dir', 'ballc_X', 'ballc_Y',
#        'ballc_o_rad_std', 'ballc_dir_rad_std', 'ballc_speed_x'],
#       dtype='object')

# %%
force_data_smaller = force_data[['gameId', 'playId', 'frameId', 'nflId', 'displayName','position','last_frame', 'time',
       'jerseyNumber', 'club', 'season', 'week', 'ballCarrierId', 'ballCarrierDisplayName', 'playDescription', 'quarter',
       'down', 'yardsToGo', 'possessionTeam', 'defensiveTeam', 'passResult', 'expectedPoints', 'expectedPointsAdded', 
       'pff_missedTackle', 'onDefense', 'role_label','tackle','assist', 'forcedFumble','pff_missedTackle','repulse_x', 'repulse_y',
    'repulse_total', 'indiv_F_theta','repulse_y_x_ratio', 'ballc_f_x_total', 'ballc_f_y_total', 'ballc_total_F_theta', 'ballc_total_F_ratio']]

# %%
force_data_smaller.week.value_counts()
# Out:
# week
# 5    1476232
# 4    1418686
# 3    1415788
# 1    1407439
# 8    1406772
# 2    1371600
# 7    1291493
# 6    1249365
# 9    1150023
# Name: count, dtype: int64

# %%
force_data_smaller
# Out:
#               gameId  playId  frameId    nflId     displayName position  \
# 0         2022090800      56        1  35472.0  Rodger Saffold        G
# 1         2022090800      56        2  35472.0  Rodger Saffold        G
# 2         2022090800      56        3  35472.0  Rodger Saffold        G
# 3         2022090800      56        4  35472.0  Rodger Saffold        G
# 4         2022090800      56        5  35472.0  Rodger Saffold        G
# ...              ...     ...      ...      ...             ...      ...
# 12187393  2022110700    3787       40      NaN        football     None
# 12187394  2022110700    3787       41      NaN        football     None
# 12187395  2022110700    3787       42      NaN        football     None
# 12187396  2022110700    3787       43      NaN        football     None
# 12187397  2022110700    3787       44      NaN        football     None
#
#           last_frame                        time  jerseyNumber      club  \
# 0                 22  2022-09-08 20:24:05.200000          76.0       BUF
# 1                 22  2022-09-08 20:24:05.299999          76.0       BUF
# 2                 22  2022-09-08 20:24:05.400000          76.0       BUF
# 3                 22  2022-09-08 20:24:05.500000          76.0       BUF
# 4                 22  2022-09-08 20:24:05.599999          76.0       BUF
# ...              ...                         ...           ...       ...
# 12187393          44  2022-11-07 23:06:49.200000           NaN  football
# 12187394          44  2022-11-07 23:06:49.299999           NaN  football
# 12187395          44  2022-11-07 23:06:49.400000           NaN  football
# 12187396          44  2022-11-07 23:06:49.500000           NaN  football
# 12187397          44  2022-11-07 23:06:49.599999           NaN  football
#
#           season  week  ballCarrierId ballCarrierDisplayName  \
# 0           2022     1          42489           Stefon Diggs
# 1           2022     1          42489           Stefon Diggs
# 2           2022     1          42489           Stefon Diggs
# 3           2022     1          42489           Stefon Diggs
# 4           2022     1          42489           Stefon Diggs
# ...          ...   ...            ...                    ...
# 12187393    2022     9          43525      Dwayne Washington
# 12187394    2022     9          43525      Dwayne Washington
# 12187395    2022     9          43525      Dwayne Washington
# 12187396    2022     9          43525      Dwayne Washington
# 12187397    2022     9          43525      Dwayne Washington
#
#                                             playDescription  quarter  down  \
# 0         (15:00) (Shotgun) J.Allen pass short right to ...        1     1
# 1         (15:00) (Shotgun) J.Allen pass short right to ...        1     1
# 2         (15:00) (Shotgun) J.Allen pass short right to ...        1     1
# 3         (15:00) (Shotgun) J.Allen pass short right to ...        1     1
# 4         (15:00) (Shotgun) J.Allen pass short right to ...        1     1
# ...                                                     ...      ...   ...
# 12187393  (:23) (Shotgun) D.Washington right guard to NO...        4     1
# 12187394  (:23) (Shotgun) D.Washington right guard to NO...        4     1
# 12187395  (:23) (Shotgun) D.Washington right guard to NO...        4     1
# 12187396  (:23) (Shotgun) D.Washington right guard to NO...        4     1
# 12187397  (:23) (Shotgun) D.Washington right guard to NO...        4     1
#
#           yardsToGo possessionTeam defensiveTeam passResult  expectedPoints  \
# 0                10            BUF            LA          C        1.298699
# 1                10            BUF            LA          C        1.298699
# 2                10            BUF            LA          C        1.298699
# 3                10            BUF            LA          C        1.298699
# 4                10            BUF            LA          C        1.298699
# ...             ...            ...           ...        ...             ...
# 12187393         10             NO           BAL       None        0.072230
# 12187394         10             NO           BAL       None        0.072230
# 12187395         10             NO           BAL       None        0.072230
# 12187396         10             NO           BAL       None        0.072230
# 12187397         10             NO           BAL       None        0.072230
#
#           expectedPointsAdded  pff_missedTackle  onDefense role_label  tackle  \
# 0                     0.00442               NaN      False    Offense     NaN
# 1                     0.00442               NaN      False    Offense     NaN
# 2                     0.00442               NaN      False    Offense     NaN
# 3                     0.00442               NaN      False    Offense     NaN
# 4                     0.00442               NaN      False    Offense     NaN
# ...                       ...               ...        ...        ...     ...
# 12187393             -0.07223               NaN      False   Football     NaN
# 12187394             -0.07223               NaN      False   Football     NaN
# 12187395             -0.07223               NaN      False   Football     NaN
# 12187396             -0.07223               NaN      False   Football     NaN
# 12187397             -0.07223               NaN      False   Football     NaN
#
#           assist  forcedFumble  pff_missedTackle  repulse_x  repulse_y  \
# 0            NaN           NaN               NaN        NaN        NaN
# 1            NaN           NaN               NaN        NaN        NaN
# 2            NaN           NaN               NaN        NaN        NaN
# 3            NaN           NaN               NaN        NaN        NaN
# 4            NaN           NaN               NaN        NaN        NaN
# ...          ...           ...               ...        ...        ...
# 12187393     NaN           NaN               NaN        NaN        NaN
# 12187394     NaN           NaN               NaN        NaN        NaN
# 12187395     NaN           NaN               NaN        NaN        NaN
# 12187396     NaN           NaN               NaN        NaN        NaN
# 12187397     NaN           NaN               NaN        NaN        NaN
#
#           repulse_total  indiv_F_theta  repulse_y_x_ratio  ballc_f_x_total  \
# 0                   NaN            NaN                NaN         0.202956
# 1                   NaN            NaN                NaN         0.249783
# 2                   NaN            NaN                NaN         0.318723
# 3                   NaN            NaN                NaN         0.389610
# 4                   NaN            NaN                NaN         0.483223
# ...                 ...            ...                ...              ...
# 12187393            NaN            NaN                NaN         1.258922
# 12187394            NaN            NaN                NaN         0.818971
# 12187395            NaN            NaN                NaN         0.255067
# 12187396            NaN            NaN                NaN        -0.364420
# 12187397            NaN            NaN                NaN        -0.697654
#
#           ballc_f_y_total  ballc_total_F_theta  ballc_total_F_ratio
# 0                0.451391             1.148256             2.224084
# 1                0.477046             1.088445             1.909842
# 2                0.465033             0.969952             1.459052
# 3                0.469144             0.877750             1.204138
# 4                0.508070             0.810458             1.051419
# ...                   ...                  ...                  ...
# 12187393         1.047871             0.694161             0.832356
# 12187394         1.439980             1.053681             1.758280
# 12187395         1.787869             1.429087             7.009411
# 12187396         1.730239             1.778381            -4.747926
# 12187397         1.983348             1.909035            -2.842881
#
# [12187398 rows x 39 columns]

# %%
overall_force_data = force_data_smaller.groupby('nflId').apply(func = overall_tackler_stats).reset_index()

# %%
overall_force_data.query('onDefense == True').drop_duplicates('nflId').total_plays.quantile(.25)
# Out:
# 44.25

# %%
overall_force_data.drop_duplicates('nflId').query('displayName == "Aaron Donald"')
# Out:
#           nflId  level_1      gameId  playId  frameId   displayName position  \
# 983457  41239.0       44  2022090800      56        1  Aaron Donald       DT
#
#         last_frame                        time  jerseyNumber club  season  \
# 983457          22  2022-09-08 20:24:05.200000          99.0   LA    2022
#
#         week  ballCarrierId ballCarrierDisplayName  \
# 983457     1          42489           Stefon Diggs
#
#                                           playDescription  quarter  down  \
# 983457  (15:00) (Shotgun) J.Allen pass short right to ...        1     1
#
#         yardsToGo possessionTeam defensiveTeam passResult  expectedPoints  \
# 983457         10            BUF            LA          C        1.298699
#
#         expectedPointsAdded  pff_missedTackle  onDefense role_label  tackle  \
# 983457              0.00442               NaN       True    Defense     NaN
#
#         assist  forcedFumble  pff_missedTackle  repulse_x  repulse_y  \
# 983457     NaN           NaN               NaN   0.025339   0.022818
#
#         repulse_total  indiv_F_theta  repulse_y_x_ratio  ballc_f_x_total  \
# 983457       0.034099       0.733097            0.90051         0.202956
#
#         ballc_f_y_total  ballc_total_F_theta  ballc_total_F_ratio  \
# 983457         0.451391             1.148256             2.224084
#
#         num_tackles  total_plays  overal_tackle_pct
# 983457           29          314           0.092357

# %%
overall_force_data.drop_duplicates('nflId').query('role_label == "Defense"').sort_values(by = 'num_tackles', ascending = False).head(10)
# Out:
#            nflId  level_1      gameId  playId  frameId       displayName  \
# 1013357  41243.0   749280  2022091107     202        1       C.J. Mosley
# 5606773  46269.0   925845  2022091109     338        1  Foyesade Oluokun
# 7879161  52435.0  1328709  2022091200     286        1     Jordyn Brooks
# 4681704  46091.0    85830  2022091100     301        1     Rashaan Evans
# 5694035  46304.0   567633  2022091105     166        1    Zaire Franklin
# 4510085  46077.0   267063  2022091102     145        1      Roquan Smith
# 7524671  48516.0   463770  2022091104      58        1      T.J. Edwards
# 1848735  42427.0  1174492  2022091112     573        1      Jordan Hicks
# 9683918  53489.0    80132  2022091100      57        1       Pete Werner
# 9852199  53509.0  1091605  2022091111      76        1     Divine Deablo
#
#         position  last_frame                        time  jerseyNumber club  \
# 1013357      ILB          32  2022-09-11 13:12:14.700000          57.0  NYJ
# 5606773      ILB          52  2022-09-11 13:15:35.200000          23.0  JAX
# 7879161      ILB          56  2022-09-12 20:25:15.299999          56.0  SEA
# 4681704      ILB          50  2022-09-11 13:15:10.099999          54.0  ATL
# 5694035      OLB          78  2022-09-11 13:08:11.200000          44.0  IND
# 4510085      ILB          53  2022-09-11 13:07:38.200000          58.0  CHI
# 7524671      ILB          20  2022-09-11 13:05:02.799999          57.0  PHI
# 1848735      ILB          50  2022-09-11 16:50:30.200000          58.0  MIN
# 9683918      OLB          46  2022-09-11 13:04:58.799999          20.0   NO
# 9852199      OLB          11  2022-09-11 16:27:31.799999           5.0   LV
#
#          season  week  ballCarrierId ballCarrierDisplayName  \
# 1013357    2022     1          53456         Rashod Bateman
# 5606773    2022     1          44852          Curtis Samuel
# 7879161    2022     1          48096            Andrew Beck
# 4681704    2022     1          44879           Alvin Kamara
# 5694035    2022     1          54572          Dameon Pierce
# 4510085    2022     1          52433          Brandon Aiyuk
# 7524671    2022     1          52443          D'Andre Swift
# 1848735    2022     1          52470            A.J. Dillon
# 9683918    2022     1          42345         Marcus Mariota
# 9852199    2022     1          40024           Keenan Allen
#
#                                            playDescription  quarter  down  \
# 1013357  (13:42) L.Jackson pass short right to R.Batema...        1     1
# 5606773  (11:45) (Shotgun) C.Samuel right guard to WAS ...        1     2
# 7879161  (11:18) R.Wilson pass short right to A.Beck to...        1     2
# 4681704  (10:40) A.Kamara right tackle to NO 26 for 1 y...        1     1
# 5694035  (12:36) (No Huddle) D.Pierce up the middle to ...        1     2
# 4510085  (13:30) B.Aiyuk left end to 50 for 7 yards (R....        1     1
# 7524671  (15:00) J.Goff pass short left to D.Swift to D...        1     1
# 1848735  (4:50) (Shotgun) A.Dillon right guard to MIN 4...        1     2
# 9683918  (15:00) (Shotgun) M.Mariota scrambles right en...        1     1
# 9852199  (14:43) (No Huddle) J.Herbert pass short right...        1     2
#
#          yardsToGo possessionTeam defensiveTeam passResult  expectedPoints  \
# 1013357         10            BAL           NYJ          C        1.386474
# 5606773         10            WAS           JAX       None        0.823197
# 7879161         10            DEN           SEA          C       -0.279236
# 4681704         10             NO           ATL       None        1.348947
# 5694035          6            HOU           IND       None        1.055910
# 4510085         10             SF           CHI       None        2.528854
# 7524671         10            DET           PHI          C        1.298699
# 1848735          6             GB           MIN       None        2.699541
# 9683918         10            ATL            NO          R        1.298699
# 9852199          2            LAC            LV          C        1.360360
#
#          expectedPointsAdded  pff_missedTackle  onDefense role_label  tackle  \
# 1013357             0.062406               NaN       True    Defense     NaN
# 5606773            -0.461443               0.0       True    Defense     0.0
# 7879161             2.353510               NaN       True    Defense     NaN
# 4681704            -0.585316               0.0       True    Defense     0.0
# 5694035            -0.369686               NaN       True    Defense     NaN
# 4510085             0.417055               0.0       True    Defense     1.0
# 7524671            -1.046330               NaN       True    Defense     NaN
# 1848735            -1.151004               0.0       True    Defense     0.0
# 9683918             0.727155               0.0       True    Defense     1.0
# 9852199            -0.017795               NaN       True    Defense     NaN
#
#          assist  forcedFumble  pff_missedTackle  repulse_x  repulse_y  \
# 1013357     NaN           NaN               NaN   0.022467  -0.010195
# 5606773     1.0           0.0               0.0   0.013543  -0.003034
# 7879161     NaN           NaN               NaN   0.013831  -0.044295
# 4681704     1.0           0.0               0.0  -0.000962   0.000962
# 5694035     NaN           NaN               NaN  -0.003079   0.000328
# 4510085     0.0           0.0               0.0  -0.003252   0.019016
# 7524671     NaN           NaN               NaN   0.020226   0.001251
# 1848735     1.0           0.0               0.0   0.000222  -0.000741
# 9683918     0.0           0.0               0.0  -0.006062   0.004728
# 9852199     NaN           NaN               NaN  -0.012499  -0.005745
#
#          repulse_total  indiv_F_theta  repulse_y_x_ratio  ballc_f_x_total  \
# 1013357       0.024672      -0.425994          -0.453782        -0.019958
# 5606773       0.013879      -0.220362          -0.224000         0.047172
# 7879161       0.046404      -1.268144          -3.202615         0.158852
# 4681704       0.001360      -0.785398          -1.000000         0.004872
# 5694035       0.003096      -0.105984          -0.106383        -0.003233
# 4510085       0.019292      -1.401420          -5.847458        -0.064249
# 7524671       0.020264       0.061755           0.061834         0.214399
# 1848735       0.000773      -1.279340          -3.333333         0.009081
# 9683918       0.007688      -0.662426          -0.780000        -0.242846
# 9852199       0.013756       0.430805           0.459596        18.430035
#
#          ballc_f_y_total  ballc_total_F_theta  ballc_total_F_ratio  \
# 1013357        -0.124379            -1.729900             6.232077
# 5606773         0.008905             0.186589             0.188785
# 7879161        -0.245894            -0.997224            -1.547940
# 4681704         0.019305             1.323604             3.962694
# 5694035         0.001126             2.806577            -0.348138
# 4510085         0.341009             1.757021            -5.307630
# 7524671         0.159427             0.639392             0.743599
# 1848735        -0.043752            -1.366147            -4.818000
# 9683918        -0.569390            -1.973939             2.344649
# 9852199         2.381608             0.128512             0.129224
#
#          num_tackles  total_plays  overal_tackle_pct
# 1013357           86          413           0.208232
# 5606773           85          415           0.204819
# 7879161           84          428           0.196262
# 4681704           84          452           0.185841
# 5694035           83          417           0.199041
# 4510085           82          403           0.203474
# 7524671           74          342           0.216374
# 1848735           74          345           0.214493
# 9683918           73          340           0.214706
# 9852199           73          340           0.214706

# %%
force_data_rel = overall_force_data[(overall_force_data['frameId'] >= 6) | (overall_force_data['frameId'] <= (overall_force_data['last_frame'] - 5))]

# %%
force_data_rel_completion = force_data_rel.query('passResult == "C" & onDefense == True')

# %%
def agg_max_func(agg_max):
    agg_max['player_avg'] = agg_max.groupby(['nflId'])['repulse_total'].transform(np.average)
    agg_max['player_sum'] = agg_max.groupby(['nflId'])['repulse_total'].transform(np.sum)
    return agg_max

# %%
force_data_rel_completion
# Out:
#             nflId  level_1      gameId  playId  frameId      displayName  \
# 73810     33131.0   763194  2022091107     868        1  Calais Campbell
# 73811     33131.0   763195  2022091107     868        2  Calais Campbell
# 73812     33131.0   763196  2022091107     868        3  Calais Campbell
# 73813     33131.0   763197  2022091107     868        4  Calais Campbell
# 73814     33131.0   763198  2022091107     868        5  Calais Campbell
# ...           ...      ...         ...     ...      ...              ...
# 11656826  55241.0  2657378  2022091900    3024       28      C.J. Brewer
# 11656827  55241.0  2657379  2022091900    3024       29      C.J. Brewer
# 11656828  55241.0  2657380  2022091900    3024       30      C.J. Brewer
# 11656829  55241.0  2657381  2022091900    3024       31      C.J. Brewer
# 11656830  55241.0  2657382  2022091900    3024       32      C.J. Brewer
#
#          position  last_frame                        time  jerseyNumber club  \
# 73810          DE          54  2022-09-11 13:42:32.900000          93.0  BAL
# 73811          DE          54  2022-09-11 13:42:33.000000          93.0  BAL
# 73812          DE          54  2022-09-11 13:42:33.099999          93.0  BAL
# 73813          DE          54  2022-09-11 13:42:33.200000          93.0  BAL
# 73814          DE          54  2022-09-11 13:42:33.299999          93.0  BAL
# ...           ...         ...                         ...           ...  ...
# 11656826       DT          32  2022-09-19 21:47:23.400000          98.0  BUF
# 11656827       DT          32  2022-09-19 21:47:23.500000          98.0  BUF
# 11656828       DT          32  2022-09-19 21:47:23.599999          98.0  BUF
# 11656829       DT          32  2022-09-19 21:47:23.700000          98.0  BUF
# 11656830       DT          32  2022-09-19 21:47:23.799999          98.0  BUF
#
#           season  week  ballCarrierId ballCarrierDisplayName  \
# 73810       2022     1          54475         Garrett Wilson
# 73811       2022     1          54475         Garrett Wilson
# 73812       2022     1          54475         Garrett Wilson
# 73813       2022     1          54475         Garrett Wilson
# 73814       2022     1          54475         Garrett Wilson
# ...          ...   ...            ...                    ...
# 11656826    2022     2          43334          Derrick Henry
# 11656827    2022     2          43334          Derrick Henry
# 11656828    2022     2          43334          Derrick Henry
# 11656829    2022     2          43334          Derrick Henry
# 11656830    2022     2          43334          Derrick Henry
#
#                                             playDescription  quarter  down  \
# 73810     (3:07) (Shotgun) J.Flacco pass short right to ...        1     3
# 73811     (3:07) (Shotgun) J.Flacco pass short right to ...        1     3
# 73812     (3:07) (Shotgun) J.Flacco pass short right to ...        1     3
# 73813     (3:07) (Shotgun) J.Flacco pass short right to ...        1     3
# 73814     (3:07) (Shotgun) J.Flacco pass short right to ...        1     3
# ...                                                     ...      ...   ...
# 11656826  (4:24) (No Huddle, Shotgun) R.Tannehill pass s...        3     2
# 11656827  (4:24) (No Huddle, Shotgun) R.Tannehill pass s...        3     2
# 11656828  (4:24) (No Huddle, Shotgun) R.Tannehill pass s...        3     2
# 11656829  (4:24) (No Huddle, Shotgun) R.Tannehill pass s...        3     2
# 11656830  (4:24) (No Huddle, Shotgun) R.Tannehill pass s...        3     2
#
#           yardsToGo possessionTeam defensiveTeam passResult  expectedPoints  \
# 73810            10            NYJ           BAL          C        0.328657
# 73811            10            NYJ           BAL          C        0.328657
# 73812            10            NYJ           BAL          C        0.328657
# 73813            10            NYJ           BAL          C        0.328657
# 73814            10            NYJ           BAL          C        0.328657
# ...             ...            ...           ...        ...             ...
# 11656826          2            TEN           BUF          C        2.867526
# 11656827          2            TEN           BUF          C        2.867526
# 11656828          2            TEN           BUF          C        2.867526
# 11656829          2            TEN           BUF          C        2.867526
# 11656830          2            TEN           BUF          C        2.867526
#
#           expectedPointsAdded  pff_missedTackle  onDefense role_label  tackle  \
# 73810               -0.212017               0.0       True    Defense     0.0
# 73811               -0.212017               0.0       True    Defense     0.0
# 73812               -0.212017               0.0       True    Defense     0.0
# 73813               -0.212017               0.0       True    Defense     0.0
# 73814               -0.212017               0.0       True    Defense     0.0
# ...                       ...               ...        ...        ...     ...
# 11656826            -1.479203               NaN       True    Defense     NaN
# 11656827            -1.479203               NaN       True    Defense     NaN
# 11656828            -1.479203               NaN       True    Defense     NaN
# 11656829            -1.479203               NaN       True    Defense     NaN
# 11656830            -1.479203               NaN       True    Defense     NaN
#
#           assist  forcedFumble  pff_missedTackle  repulse_x  repulse_y  \
# 73810        1.0           0.0               0.0  -0.008936   0.004931
# 73811        1.0           0.0               0.0  -0.009499   0.005665
# 73812        1.0           0.0               0.0  -0.010037   0.006158
# 73813        1.0           0.0               0.0  -0.010800   0.006745
# 73814        1.0           0.0               0.0  -0.011170   0.007144
# ...          ...           ...               ...        ...        ...
# 11656826     NaN           NaN               NaN   1.398587   2.638571
# 11656827     NaN           NaN               NaN   1.155835   1.692047
# 11656828     NaN           NaN               NaN   0.952802   0.973074
# 11656829     NaN           NaN               NaN   0.752008   0.611523
# 11656830     NaN           NaN               NaN   0.595017   0.250911
#
#           repulse_total  indiv_F_theta  repulse_y_x_ratio  ballc_f_x_total  \
# 73810          0.010206      -0.504264          -0.551852        -0.037428
# 73811          0.011060      -0.537717          -0.596330        -0.029992
# 73812          0.011775      -0.550325          -0.613553        -0.022723
# 73813          0.012734      -0.558275          -0.624549        -0.011544
# 73814          0.013259      -0.568998          -0.639556         0.000139
# ...                 ...            ...                ...              ...
# 11656826       2.986319       1.083395           1.886598        15.180639
# 11656827       2.049141       0.971504           1.463917      1304.368512
# 11656828       1.361875       0.795924           1.021277        27.118875
# 11656829       0.969266       0.682730           0.813187         7.092155
# 11656830       0.645757       0.399061           0.421687         4.158732
#
#           ballc_f_y_total  ballc_total_F_theta  ballc_total_F_ratio  \
# 73810            0.072364             2.048129            -1.933395
# 73811            0.085823             1.906990            -2.861559
# 73812            0.098053             1.798517            -4.315178
# 73813            0.109775             1.675571            -9.509365
# 73814            0.121447             1.569656           876.777442
# ...                   ...                  ...                  ...
# 11656826         2.276539             0.148854             0.149963
# 11656827      -106.773290            -0.081676            -0.081858
# 11656828        -3.529338            -0.129416            -0.130143
# 11656829        -1.100895            -0.153998            -0.155227
# 11656830        -1.506107            -0.347462            -0.362155
#
#           num_tackles  total_plays  overal_tackle_pct
# 73810              18          237           0.075949
# 73811              18          237           0.075949
# 73812              18          237           0.075949
# 73813              18          237           0.075949
# 73814              18          237           0.075949
# ...               ...          ...                ...
# 11656826            2           15           0.133333
# 11656827            2           15           0.133333
# 11656828            2           15           0.133333
# 11656829            2           15           0.133333
# 11656830            2           15           0.133333
#
# [1776324 rows x 43 columns]

# %%
force_data_rel_completion_agg = agg_max_func(force_data_rel_completion)
# Out:
# /tmp/ipykernel_42/2607593729.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   agg_max['player_avg'] = agg_max.groupby(['nflId'])['repulse_total'].transform(np.average)
# /tmp/ipykernel_42/2607593729.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   agg_max['player_sum'] = agg_max.groupby(['nflId'])['repulse_total'].transform(np.sum)

# %%
force_data_rel_completion_agg.query('total_plays >= 50').drop_duplicates('nflId').sort_values('player_avg', ascending = False).reset_index()
# Out:
#        index    nflId   level_1      gameId  playId  frameId  \
# 0    1324681  41483.0   3524645  2022092507     501        1
# 1    1041838  41256.0   9366763  2022102310     335        1
# 2    2489100  43325.0    376694  2022091103     295        1
# 3    5303427  46175.0   4024531  2022092513      86        1
# 4    2893942  43420.0   7034702  2022101000    1427        1
# ..       ...      ...       ...         ...     ...      ...
# 624  7564906  48566.0    931540  2022091109     563        1
# 625  8878646  52650.0   1172472  2022091112     181        1
# 626   544297  38619.0   1238181  2022091113      65        1
# 627  3910372  44922.0  10165255  2022103004     870        1
# 628  7539009  48520.0     91224  2022091100     522        1
#
#            displayName position  last_frame                        time  \
# 0    Terrance Mitchell       CB          19  2022-09-25 13:19:43.200000
# 1          Jimmie Ward       FS          31  2022-10-23 16:35:56.599999
# 2           Myles Jack      ILB          23  2022-09-11 13:16:13.400000
# 3         Josey Jewell      ILB          51  2022-09-25 20:24:03.700000
# 4       Blake Martinez      ILB          13  2022-10-10 21:18:33.400000
# ..                 ...      ...         ...                         ...
# 624        Daniel Wise       DE          19  2022-09-11 13:29:11.200000
# 625    Jonathan Garvin      OLB          43  2022-09-11 16:29:58.599999
# 626        Akiem Hicks       DT          22  2022-09-11 20:23:43.299999
# 627     Jaleel Johnson       DT          45  2022-10-30 16:50:16.000000
# 628       Anthony Rush       DT          34  2022-09-11 13:28:23.400000
#
#      jerseyNumber club  season  week  ballCarrierId    ballCarrierDisplayName  \
# 0            39.0  TEN    2022     3          47807               Josh Jacobs
# 1             1.0   SF    2022     7          47839            Mecole Hardman
# 2            51.0  PIT    2022     1          43344                Tyler Boyd
# 3            47.0  DEN    2022     3          47819              Deebo Samuel
# 4            54.0   LV    2022     5          46243  Marquez Valdes-Scantling
# ..            ...  ...     ...   ...            ...                       ...
# 624          92.0  WAS    2022     1          44849                 Zay Jones
# 625          53.0   GB    2022     1          52430          Justin Jefferson
# 626          96.0   TB    2022     1          46206            Dalton Schultz
# 627          90.0  HOU    2022     8          43334             Derrick Henry
# 628          94.0  ATL    2022     1          48415              Deonte Harty
#
#                                        playDescription  quarter  down  \
# 0    (5:53) (Shotgun) D.Carr pass short left to J.J...        1     2
# 1    (9:43) (Shotgun) P.Mahomes pass short left to ...        1     2
# 2    (11:34) (No Huddle, Shotgun) J.Burrow pass sho...        1     1
# 3    (14:19) J.Garoppolo pass short left to D.Samue...        1     2
# 4    (6:15) (Shotgun) P.Mahomes pass short middle t...        2     1
# ..                                                 ...      ...   ...
# 624  (7:12) (Shotgun) T.Lawrence pass short left to...        1     2
# 625  (11:35) (Shotgun) K.Cousins pass short right t...        1     2
# 626  (14:56) (Shotgun) D.Prescott pass short left t...        1     1
# 627  (13:31) M.Willis pass short right to D.Henry t...        2     1
# 628  (7:12) (Shotgun) J.Winston pass short right to...        1     2
#
#      yardsToGo possessionTeam defensiveTeam passResult  expectedPoints  \
# 0           14             LV           TEN          C        2.566176
# 1            8             KC            SF          C        0.815707
# 2           10            CIN           PIT          C        2.435449
# 3            8             SF           DEN          C       -0.329895
# 4           10             KC            LV          C        4.292064
# ..         ...            ...           ...        ...             ...
# 624          8            JAX           WAS          C        0.838833
# 625          5            MIN            GB          C        3.572353
# 626         10            DAL            TB          C        0.444005
# 627         10            TEN           HOU          C        0.676076
# 628          5             NO           ATL          C        1.453144
#
#      expectedPointsAdded  pff_missedTackle  onDefense role_label  tackle  \
# 0              -1.315406               NaN       True    Defense     NaN
# 1              -0.763247               NaN       True    Defense     NaN
# 2              -0.338776               0.0       True    Defense     0.0
# 3               1.663811               NaN       True    Defense     NaN
# 4               0.859268               NaN       True    Defense     NaN
# ..                   ...               ...        ...        ...     ...
# 624            -0.490157               NaN       True    Defense     NaN
# 625             1.524514               NaN       True    Defense     NaN
# 626             0.224793               NaN       True    Defense     NaN
# 627             0.682049               NaN       True    Defense     NaN
# 628             0.525798               NaN       True    Defense     NaN
#
#      assist  forcedFumble  pff_missedTackle  repulse_x  repulse_y  \
# 0       NaN           NaN               NaN   0.000290   0.011271
# 1       NaN           NaN               NaN  -0.008569  -0.034275
# 2       1.0           0.0               0.0   0.068416   0.047183
# 3       NaN           NaN               NaN   0.013806  -0.026435
# 4       NaN           NaN               NaN   0.000208  -0.027095
# ..      ...           ...               ...        ...        ...
# 624     NaN           NaN               NaN  -0.002047   0.013824
# 625     NaN           NaN               NaN   0.001676  -0.007917
# 626     NaN           NaN               NaN   0.015828   0.011750
# 627     NaN           NaN               NaN   0.000466  -0.007224
# 628     NaN           NaN               NaN   0.004951   0.008453
#
#      repulse_total  indiv_F_theta  repulse_y_x_ratio  ballc_f_x_total  \
# 0         0.011274       1.545051          38.833333         0.606485
# 1         0.035330       1.325818           4.000000         0.003732
# 2         0.083108       0.603749           0.689655         0.050189
# 3         0.029823      -1.089489          -1.914706         0.111103
# 4         0.027096      -1.563104        -129.999998        -0.001400
# ..             ...            ...                ...              ...
# 624       0.013975      -1.423801          -6.753846         0.170400
# 625       0.008093      -1.362197          -4.724138        -0.089676
# 626       0.019713       0.638575           0.742331         1.508966
# 627       0.007239      -1.506418         -15.511628         0.097223
# 628       0.009797       1.040947           1.707317         0.324855
#
#      ballc_f_y_total  ballc_total_F_theta  ballc_total_F_ratio  num_tackles  \
# 0           0.987888             1.020204             1.628875           23
# 1           0.035564             1.466243             9.529583            7
# 2          -0.156302            -1.260095            -3.114281           67
# 3          -0.128589            -0.858220            -1.157382           35
# 4          -0.292083            -1.575589           208.649746           20
# ..               ...                  ...                  ...          ...
# 624         0.198743             0.862027             1.166328            2
# 625        -0.107036            -2.268171             1.193588            4
# 626        -0.527786            -0.336467            -0.349766            5
# 627         0.119416             0.887486             1.228273            3
# 628         0.434915             0.929257             1.338797            7
#
#      total_plays  overal_tackle_pct  player_avg    player_sum
# 0            137           0.167883    4.470590  10930.593075
# 1             76           0.092105    4.277116   5483.263169
# 2            340           0.197059    3.947524  16824.347839
# 3            164           0.213415    3.898201   6892.019089
# 4             93           0.215054    3.796134   3879.649197
# ..           ...                ...         ...           ...
# 624           50           0.040000    0.021556      8.751675
# 625           65           0.061538    0.021270     14.165792
# 626           58           0.086207    0.020309     11.677571
# 627           53           0.056604    0.018070      7.011116
# 628           71           0.098592    0.017013     11.568719
#
# [629 rows x 46 columns]

# %%
force_data_rel_completion_agg.position.unique()
# Out:
# array(['DE', 'NT', 'SS', 'FS', 'OLB', 'DT', 'CB', 'ILB', 'MLB', None,
#        'DB', 'WR'], dtype=object)

# %%
#Defensive End Rankings
force_data_rel_completion_agg.query('total_plays >= 50').query('position == "DE"').drop_duplicates('nflId').sort_values('player_avg', ascending = False).reset_index(drop = True)
# Out:
#       nflId  level_1      gameId  playId  frameId       displayName position  \
# 0   54491.0   753435  2022091107     301        1  Jermaine Johnson       DE
# 1   53450.0   579317  2022091105     503        1        Kwity Paye       DE
# 2   48462.0   857974  2022091108    1354        1      Kevin Strong       DE
# 3   52641.0   922085  2022091109     163        1     Casey Toohill       DE
# 4   54467.0   478741  2022091104     689        1  Aidan Hutchinson       DE
# ..      ...      ...         ...     ...      ...               ...      ...
# 88  38589.0  7378828  2022101602     553        1       Vinny Curry       DE
# 89  44813.0   172851  2022091101      85        1     Myles Garrett       DE
# 90  37841.0  5998901  2022100903     411        1     Mario Addison       DE
# 91  42436.0   190550  2022091101     662        1    Henry Anderson       DE
# 92  48566.0   931540  2022091109     563        1       Daniel Wise       DE
#
#     last_frame                        time  jerseyNumber club  season  week  \
# 0           38  2022-09-11 13:14:38.799999          52.0  NYJ    2022     1
# 1           28  2022-09-11 13:23:05.299999          51.0  IND    2022     1
# 2           25  2022-09-11 17:24:35.099999          97.0  TEN    2022     1
# 3           24  2022-09-11 13:07:49.099999          95.0  WAS    2022     1
# 4           32  2022-09-11 13:31:34.700000          97.0  DET    2022     1
# ..         ...                         ...           ...  ...     ...   ...
# 88          37  2022-10-16 13:27:05.700000          99.0  NYJ    2022     6
# 89          26  2022-09-11 13:05:42.500000          95.0  CLE    2022     1
# 90          34  2022-10-09 13:18:37.500000          97.0  HOU    2022     5
# 91          32  2022-09-11 13:28:22.799999          94.0  CAR    2022     1
# 92          19  2022-09-11 13:29:11.200000          92.0  WAS    2022     1
#
#     ballCarrierId ballCarrierDisplayName  \
# 0           52500         Devin Duvernay
# 1           41246          Brandin Cooks
# 2           46071         Saquon Barkley
# 3           44849              Zay Jones
# 4           47834             A.J. Brown
# ..            ...                    ...
# 88          44995            Aaron Jones
# 89          44820    Christian McCaffrey
# 90          38696           Marvin Jones
# 91          42347           Amari Cooper
# 92          44849              Zay Jones
#
#                                       playDescription  quarter  down  \
# 0   (11:19) (Shotgun) L.Jackson pass short left to...        1     2
# 1   (5:13) (Shotgun) D.Mills pass short left to B....        1     1
# 2   (5:29) D.Jones pass short middle to S.Barkley ...        2     1
# 3   (14:14) T.Lawrence pass short left to Z.Jones ...        1     1
# 4   (5:51) (Shotgun) J.Hurts pass short middle to ...        1     1
# ..                                                ...      ...   ...
# 88  (7:48) A.Rodgers pass short right to A.Jones t...        1     1
# 89  (14:53) (Shotgun) B.Mayfield pass short left t...        1     2
# 90  (8:31) (No Huddle, Shotgun) T.Lawrence pass sh...        1     1
# 91  (2:58) (Shotgun) J.Brissett pass short right t...        1     1
# 92  (7:12) (Shotgun) T.Lawrence pass short left to...        1     2
#
#     yardsToGo possessionTeam defensiveTeam passResult  expectedPoints  \
# 0          10            BAL           NYJ          C        1.858800
# 1          10            HOU           IND          C        1.359446
# 2          10            NYG           TEN          C        1.455218
# 3          10            JAX           WAS          C        2.950350
# 4          15            PHI           DET          C       -0.162443
# ..        ...            ...           ...        ...             ...
# 88         10             GB           NYJ          C        0.966555
# 89         10            CAR           CLE          C        0.206872
# 90         10            JAX           HOU          C        3.166933
# 91         10            CLE           CAR          C        2.984115
# 92          8            JAX           WAS          C        0.838833
#
#     expectedPointsAdded  pff_missedTackle  onDefense role_label  tackle  \
# 0              0.045612               NaN       True    Defense     NaN
# 1             -0.567517               NaN       True    Defense     NaN
# 2             -0.315693               NaN       True    Defense     NaN
# 3              1.057423               NaN       True    Defense     NaN
# 4              0.912367               NaN       True    Defense     NaN
# ..                  ...               ...        ...        ...     ...
# 88             0.200364               NaN       True    Defense     NaN
# 89            -1.836262               NaN       True    Defense     NaN
# 90            -0.455318               NaN       True    Defense     NaN
# 91            -0.406759               NaN       True    Defense     NaN
# 92            -0.490157               NaN       True    Defense     NaN
#
#     assist  forcedFumble  pff_missedTackle  repulse_x  repulse_y  \
# 0      NaN           NaN               NaN   0.002392   0.011315
# 1      NaN           NaN               NaN   0.013769   0.000479
# 2      NaN           NaN               NaN   0.006823   0.016035
# 3      NaN           NaN               NaN  -0.019430  -0.001905
# 4      NaN           NaN               NaN  -0.049603  -0.278109
# ..     ...           ...               ...        ...        ...
# 88     NaN           NaN               NaN  -0.009836  -0.097756
# 89     NaN           NaN               NaN   0.126598   0.196501
# 90     NaN           NaN               NaN  -0.000036   0.004444
# 91     NaN           NaN               NaN   0.006421  -0.010033
# 92     NaN           NaN               NaN  -0.002047   0.013824
#
#     repulse_total  indiv_F_theta  repulse_y_x_ratio  ballc_f_x_total  \
# 0        0.011565       1.362498           4.731183         0.282602
# 1        0.013778       0.034745           0.034759         0.196427
# 2        0.017427       1.168475           2.350000         0.207475
# 3        0.019524       0.097727           0.098039        -0.014729
# 4        0.282498       1.394296           5.606741         0.341108
# ..            ...            ...                ...              ...
# 88       0.098250       1.470518           9.938775         0.168832
# 89       0.233752       0.998465           1.552163         0.402932
# 90       0.004444      -1.562796        -125.000003         0.031750
# 91       0.011911      -1.001483          -1.562500         0.046374
# 92       0.013975      -1.423801          -6.753846         0.170400
#
#     ballc_f_y_total  ballc_total_F_theta  ballc_total_F_ratio  num_tackles  \
# 0          0.454515             1.014527             1.608325           10
# 1          0.137179             0.609634             0.698374           19
# 2          0.331969             1.012209             1.600043            9
# 3         -0.034164            -1.977845             2.319504           11
# 4         -3.101522            -1.461256            -9.092484           13
# ..              ...                  ...                  ...          ...
# 88        -0.654334            -1.318283            -3.875658            7
# 89         0.394301             0.774572             0.978579           11
# 90        -0.117166            -1.306167            -3.690253            3
# 91         0.030883             0.587510             0.665955           12
# 92         0.198743             0.862027             1.166328            2
#
#     total_plays  overal_tackle_pct  player_avg   player_sum
# 0            87           0.114943    1.057067   994.700101
# 1           181           0.104972    0.891137  2054.962037
# 2            97           0.092784    0.742186   898.045436
# 3           122           0.090164    0.689136   895.188131
# 4           321           0.040498    0.435041  1630.533970
# ..          ...                ...         ...          ...
# 88           59           0.118644    0.027479    16.487583
# 89          247           0.044534    0.024644    84.872780
# 90           91           0.032967    0.023689    31.292779
# 91           96           0.125000    0.022686    16.515110
# 92           50           0.040000    0.021556     8.751675
#
# [93 rows x 45 columns]

# %%
#DT Rankings
force_data_rel_completion_agg.query('total_plays >= 50').query('position == "NT" | position == "DT"').drop_duplicates('nflId').sort_values('player_avg', ascending = False).reset_index(drop = True)
# Out:
#        nflId   level_1      gameId  playId  frameId      displayName position  \
# 0    47841.0   1250357  2022091113     465        1     Trysten Hill       DT
# 1    53073.0    835657  2022091108     318        1       Teair Tart       DT
# 2    52422.0    274963  2022091102     364        1     Javon Kinlaw       DT
# 3    54615.0   2351300  2022091810    1400        1    Thomas Booker       DT
# 4    47867.0   1020884  2022091110     870        1  Khalen Saunders       DT
# ..       ...       ...         ...     ...      ...              ...      ...
# 121  42360.0    282314  2022091102     756        1    Arik Armstead       DT
# 122  53621.0   1248497  2022091113     413        1  Quinton Bohanna       DT
# 123  38619.0   1238181  2022091113      65        1      Akiem Hicks       DT
# 124  44922.0  10165255  2022103004     870        1   Jaleel Johnson       DT
# 125  48520.0     91224  2022091100     522        1     Anthony Rush       DT
#
#      last_frame                        time  jerseyNumber club  season  week  \
# 0            36  2022-09-11 20:37:58.700000          72.0  DAL    2022     1
# 1            28  2022-09-11 16:39:34.700000          93.0  TEN    2022     1
# 2            60  2022-09-11 13:15:51.799999          99.0   SF    2022     1
# 3            27  2022-09-18 17:16:41.400000          56.0  HOU    2022     2
# 4            27  2022-09-11 16:53:49.299999          99.0   KC    2022     1
# ..          ...                         ...           ...  ...     ...   ...
# 121          27  2022-09-11 13:35:10.400000          91.0   SF    2022     1
# 122          50  2022-09-11 20:36:42.000000          98.0  DAL    2022     1
# 123          22  2022-09-11 20:23:43.299999          96.0   TB    2022     1
# 124          45  2022-10-30 16:50:16.000000          90.0  HOU    2022     8
# 125          34  2022-09-11 13:28:23.400000          94.0  ATL    2022     1
#
#      ballCarrierId ballCarrierDisplayName  \
# 0            41233             Mike Evans
# 1            46071         Saquon Barkley
# 2            47856       David Montgomery
# 3            42358          Melvin Gordon
# 4            48646            Greg Dortch
# ..             ...                    ...
# 121          53646         Khalil Herbert
# 122          44896           Chris Godwin
# 123          46206         Dalton Schultz
# 124          43334          Derrick Henry
# 125          48415           Deonte Harty
#
#                                        playDescription  quarter  down  \
# 0    (7:58) T.Brady pass deep right to M.Evans to D...        1     2
# 1    (9:44) (Shotgun) D.Jones pass short left to S....        1     2
# 2    (9:10) (Shotgun) J.Fields pass short middle to...        1     3
# 3    (13:31) (Shotgun) R.Wilson pass short middle t...        2     3
# 4    (:04) (Shotgun) K.Murray pass deep right to G....        1     2
# ..                                                 ...      ...   ...
# 121  (3:55) J.Fields pass short left to K.Herbert t...        1     1
# 122  (9:02) (Shotgun) T.Brady pass short left to C....        1     1
# 123  (14:56) (Shotgun) D.Prescott pass short left t...        1     1
# 124  (13:31) M.Willis pass short right to D.Henry t...        2     1
# 125  (7:12) (Shotgun) J.Winston pass short right to...        1     2
#
#      yardsToGo possessionTeam defensiveTeam passResult  expectedPoints  \
# 0            8             TB           DAL          C        2.281414
# 1           10            NYG           TEN          C        0.786975
# 2            6            CHI            SF          C       -0.763683
# 3           16            DEN           HOU          C        0.367298
# 4           18            ARI            KC          C        1.183888
# ..         ...            ...           ...        ...             ...
# 121         10            CHI            SF          C        1.530588
# 122         15             TB           DAL          C        0.500792
# 123         10            DAL            TB          C        0.444005
# 124         10            TEN           HOU          C        0.676076
# 125          5             NO           ATL          C        1.453144
#
#      expectedPointsAdded  pff_missedTackle  onDefense role_label  tackle  \
# 0               1.738313               NaN       True    Defense     NaN
# 1              -0.370533               NaN       True    Defense     NaN
# 2               2.563382               1.0       True    Defense     0.0
# 3              -0.876291               NaN       True    Defense     NaN
# 4               2.611672               NaN       True    Defense     NaN
# ..                   ...               ...        ...        ...     ...
# 121            -1.123506               NaN       True    Defense     NaN
# 122             2.198878               NaN       True    Defense     NaN
# 123             0.224793               NaN       True    Defense     NaN
# 124             0.682049               NaN       True    Defense     NaN
# 125             0.525798               NaN       True    Defense     NaN
#
#      assist  forcedFumble  pff_missedTackle  repulse_x  repulse_y  \
# 0       NaN           NaN               NaN  -0.001377   0.004147
# 1       NaN           NaN               NaN   0.001685   0.014401
# 2       0.0           0.0               1.0   0.024065  -0.177924
# 3       NaN           NaN               NaN   0.032182   0.063683
# 4       NaN           NaN               NaN   0.006540  -0.004215
# ..      ...           ...               ...        ...        ...
# 121     NaN           NaN               NaN  -0.017923   0.035640
# 122     NaN           NaN               NaN   0.023003   0.004700
# 123     NaN           NaN               NaN   0.015828   0.011750
# 124     NaN           NaN               NaN   0.000466  -0.007224
# 125     NaN           NaN               NaN   0.004951   0.008453
#
#      repulse_total  indiv_F_theta  repulse_y_x_ratio  ballc_f_x_total  \
# 0         0.004370      -1.250095          -3.010526        -0.214407
# 1         0.014500       1.454324           8.546875         0.210364
# 2         0.179544      -1.436357          -7.393443         0.091947
# 3         0.071353       1.102880           1.978836         0.360557
# 4         0.007781      -0.572527          -0.644540         0.046623
# ..             ...            ...                ...              ...
# 121       0.039893      -1.104839          -1.988506         0.236297
# 122       0.023478       0.201528           0.204301         0.196640
# 123       0.019713       0.638575           0.742331         1.508966
# 124       0.007239      -1.506418         -15.511628         0.097223
# 125       0.009797       1.040947           1.707317         0.324855
#
#      ballc_f_y_total  ballc_total_F_theta  ballc_total_F_ratio  num_tackles  \
# 0           0.326294             2.152145            -1.521845            7
# 1           0.149906             0.619136             0.712605           14
# 2          -0.411639            -1.351035            -4.476896            1
# 3           0.315626             0.719047             0.875384            8
# 4          -0.132666            -1.232847            -2.845508           26
# ..               ...                  ...                  ...          ...
# 121         0.128022             0.496512             0.541782            4
# 122        -0.088875            -0.424489            -0.451968            9
# 123        -0.527786            -0.336467            -0.349766            5
# 124         0.119416             0.887486             1.228273            3
# 125         0.434915             0.929257             1.338797            7
#
#      total_plays  overal_tackle_pct  player_avg   player_sum
# 0            105           0.066667    2.304657  2668.793036
# 1            168           0.083333    1.388450  3011.548566
# 2             52           0.019231    1.075614   578.680249
# 3             84           0.095238    0.944785   594.269472
# 4            127           0.204724    0.732159  1134.113694
# ..           ...                ...         ...          ...
# 121           51           0.078431    0.027697    14.125549
# 122          127           0.070866    0.025472    31.915790
# 123           58           0.086207    0.020309    11.677571
# 124           53           0.056604    0.018070     7.011116
# 125           71           0.098592    0.017013    11.568719
#
# [126 rows x 45 columns]

# %%
#Safety Rankings
force_data_rel_completion_agg.query('total_plays >= 50').query('position == "SS" | position == "FS"').drop_duplicates('nflId').sort_values('player_avg', ascending = False).reset_index(drop = True)
# Out:
#        nflId  level_1      gameId  playId  frameId      displayName position  \
# 0    41256.0  9366763  2022102310     335        1      Jimmie Ward       FS
# 1    47964.0  2657127  2022091900    3024        1   Jaquan Johnson       FS
# 2    46097.0   376924  2022091103     295        1  Terrell Edmunds       SS
# 3    48581.0  1133296  2022091111    1975        1   Roderic Teamer       SS
# 4    52613.0  2762663  2022091901    3002        1    Josh Metellus       SS
# ..       ...      ...         ...     ...      ...              ...      ...
# 98   41270.0   749344  2022091107     202        1  Lamarcus Joyner       SS
# 99   54704.0  3105570  2022092502    1325        1    Rodney Thomas       FS
# 100  48026.0      352  2022090800      56        1       Nick Scott       SS
# 101  42543.0  1328037  2022091200     286        1    Quandre Diggs       FS
# 102  46680.0  4595857  2022100203     868        1    Sean Chandler       SS
#
#      last_frame                        time  jerseyNumber club  season  week  \
# 0            31  2022-10-23 16:35:56.599999           1.0   SF    2022     7
# 1            32  2022-09-19 21:47:20.700000           4.0  BUF    2022     2
# 2            23  2022-09-11 13:16:13.400000          34.0  PIT    2022     1
# 3            19  2022-09-11 18:04:40.900000          33.0   LV    2022     1
# 4            69  2022-09-19 22:39:58.500000          44.0  MIN    2022     2
# ..          ...                         ...           ...  ...     ...   ...
# 98           32  2022-09-11 13:12:14.700000          29.0  NYJ    2022     1
# 99           23  2022-09-25 14:02:13.799999          25.0  IND    2022     3
# 100          22  2022-09-08 20:24:05.200000          33.0   LA    2022     1
# 101          56  2022-09-12 20:25:15.299999           6.0  SEA    2022     1
# 102          27  2022-10-02 16:43:58.500000          34.0  CAR    2022     4
#
#      ballCarrierId ballCarrierDisplayName  \
# 0            47839         Mecole Hardman
# 1            43334          Derrick Henry
# 2            43344             Tyler Boyd
# 3            53526           Tre' McKitty
# 4            53579       Kenneth Gainwell
# ..             ...                    ...
# 98           53456         Rashod Bateman
# 99           44874    JuJu Smith-Schuster
# 100          42489           Stefon Diggs
# 101          48096            Andrew Beck
# 102          39983              Zach Ertz
#
#                                        playDescription  quarter  down  \
# 0    (9:43) (Shotgun) P.Mahomes pass short left to ...        1     2
# 1    (4:24) (No Huddle, Shotgun) R.Tannehill pass s...        3     2
# 2    (11:34) (No Huddle, Shotgun) J.Burrow pass sho...        1     1
# 3    (11:17) (Shotgun) J.Herbert pass short middle ...        3     1
# 4    (12:41) (Shotgun) J.Hurts pass short left to K...        4     3
# ..                                                 ...      ...   ...
# 98   (13:42) L.Jackson pass short right to R.Batema...        1     1
# 99   (6:24) (Shotgun) P.Mahomes pass short left to ...        2     2
# 100  (15:00) (Shotgun) J.Allen pass short right to ...        1     1
# 101  (11:18) R.Wilson pass short right to A.Beck to...        1     2
# 102  (14:51) (Shotgun) K.Murray pass short middle t...        2     1
#
#      yardsToGo possessionTeam defensiveTeam passResult  expectedPoints  \
# 0            8             KC            SF          C        0.815707
# 1            2            TEN           BUF          C        2.867526
# 2           10            CIN           PIT          C        2.435449
# 3           10            LAC            LV          C        2.331285
# 4           14            PHI           MIN          C       -0.081736
# ..         ...            ...           ...        ...             ...
# 98          10            BAL           NYJ          C        1.386474
# 99           6             KC           IND          C        2.103809
# 100         10            BUF            LA          C        1.298699
# 101         10            DEN           SEA          C       -0.279236
# 102         10            ARI           CAR          C        0.509104
#
#      expectedPointsAdded  pff_missedTackle  onDefense role_label  tackle  \
# 0              -0.763247               NaN       True    Defense     NaN
# 1              -1.479203               NaN       True    Defense     NaN
# 2              -0.338776               NaN       True    Defense     NaN
# 3               0.768697               NaN       True    Defense     NaN
# 4              -0.313208               NaN       True    Defense     NaN
# ..                   ...               ...        ...        ...     ...
# 98              0.062406               NaN       True    Defense     NaN
# 99              0.710932               NaN       True    Defense     NaN
# 100             0.004420               NaN       True    Defense     NaN
# 101             2.353510               NaN       True    Defense     NaN
# 102            -0.321962               NaN       True    Defense     NaN
#
#      assist  forcedFumble  pff_missedTackle  repulse_x  repulse_y  \
# 0       NaN           NaN               NaN  -0.008569  -0.034275
# 1       NaN           NaN               NaN   0.000306   0.001531
# 2       NaN           NaN               NaN  -0.010355  -0.005105
# 3       NaN           NaN               NaN  -0.000099  -0.007428
# 4       NaN           NaN               NaN  -0.001333   0.001423
# ..      ...           ...               ...        ...        ...
# 98      NaN           NaN               NaN  -0.000158  -0.002224
# 99      NaN           NaN               NaN  -0.002932  -0.003095
# 100     NaN           NaN               NaN  -0.004284   0.010746
# 101     NaN           NaN               NaN   0.017234  -0.006763
# 102     NaN           NaN               NaN   0.211638   0.042328
#
#      repulse_total  indiv_F_theta  repulse_y_x_ratio  ballc_f_x_total  \
# 0         0.035330       1.325818           4.000000         0.003732
# 1         0.001561       1.373401           5.000000        -0.025250
# 2         0.011545       0.458066           0.493042         0.050189
# 3         0.007429       1.557428          74.799999         0.004771
# 4         0.001949      -0.818114          -1.067669         0.054393
# ..             ...            ...                ...              ...
# 98        0.002230       1.500048          14.111110        -0.019958
# 99        0.004263       0.812419           1.055556         0.217075
# 100       0.011569      -1.191436          -2.508333         0.202956
# 101       0.018513      -0.373942          -0.392405         0.158852
# 102       0.215829       0.197396           0.200000         0.257605
#
#      ballc_f_y_total  ballc_total_F_theta  ballc_total_F_ratio  num_tackles  \
# 0           0.035564             1.466243             9.529583            7
# 1           0.016454             2.564068            -0.651637           24
# 2          -0.156302            -1.260095            -3.114281           31
# 3           0.046708             1.469004             9.789999            9
# 4           0.070899             0.916382             1.303452           13
# ..               ...                  ...                  ...          ...
# 98         -0.124379            -1.729900             6.232077           34
# 99         -0.029685            -0.135906            -0.136749           23
# 100         0.451391             1.148256             2.224084           34
# 101        -0.245894            -0.997224            -1.547940           39
# 102         0.354965             0.943017             1.377943            7
#
#      total_plays  overal_tackle_pct  player_avg   player_sum
# 0             76           0.092105    4.277116  5483.263169
# 1            153           0.156863    2.826659  5947.289808
# 2            319           0.097179    2.351888  9012.435711
# 3             52           0.173077    2.325530  1648.800902
# 4             68           0.191176    1.886554  1533.768244
# ..           ...                ...         ...          ...
# 98           420           0.080952    0.493746  2547.728100
# 99           246           0.093496    0.466189  1365.933641
# 100          346           0.098266    0.462808  2284.881656
# 101          428           0.091121    0.401321  2206.061396
# 102           54           0.129630    0.342968   256.197416
#
# [103 rows x 45 columns]

# %%
#Linebacker Rankings
force_data_rel_completion_agg.query('total_plays >= 50').query('position == "OLB" | position == "MLB" | position == "ILB"').drop_duplicates('nflId').sort_values('player_avg', ascending = False).reset_index(drop = True)
# Out:
#        nflId  level_1      gameId  playId  frameId      displayName position  \
# 0    43325.0   376694  2022091103     295        1       Myles Jack      ILB
# 1    46175.0  4024531  2022092513      86        1     Josey Jewell      ILB
# 2    43420.0  7034702  2022101000    1427        1   Blake Martinez      ILB
# 3    47855.0   372664  2022091103      58        1   Germaine Pratt      OLB
# 4    54523.0  2115968  2022091807     839        1    Troy Andersen      ILB
# ..       ...      ...         ...     ...      ...              ...      ...
# 161  37145.0   755800  2022091107     412        1   Justin Houston      OLB
# 162  42465.0  1175520  2022091112     611        1  Za'Darius Smith      OLB
# 163  47795.0  1169452  2022091112      62        1      Rashan Gary      OLB
# 164  43292.0  1098728  2022091111     336        1        Joey Bosa      OLB
# 165  52650.0  1172472  2022091112     181        1  Jonathan Garvin      OLB
#
#      last_frame                        time  jerseyNumber club  season  week  \
# 0            23  2022-09-11 13:16:13.400000          51.0  PIT    2022     1
# 1            51  2022-09-25 20:24:03.700000          47.0  DEN    2022     3
# 2            13  2022-10-10 21:18:33.400000          54.0   LV    2022     5
# 3            21  2022-09-11 13:04:14.200000          57.0  CIN    2022     1
# 4            32  2022-09-18 16:40:54.000000          44.0  ATL    2022     2
# ..          ...                         ...           ...  ...     ...   ...
# 161          20  2022-09-11 13:20:37.299999          50.0  BAL    2022     1
# 162          16  2022-09-11 16:52:40.700000          55.0  MIN    2022     1
# 163          34  2022-09-11 16:26:32.599999          52.0   GB    2022     1
# 164          22  2022-09-11 16:35:47.599999          97.0  LAC    2022     1
# 165          43  2022-09-11 16:29:58.599999          53.0   GB    2022     1
#
#      ballCarrierId    ballCarrierDisplayName  \
# 0            43344                Tyler Boyd
# 1            47819              Deebo Samuel
# 2            46243  Marquez Valdes-Scantling
# 3            53484            Pat Freiermuth
# 4            43399              Tyler Higbee
# ..             ...                       ...
# 161          54501               Breece Hall
# 162          37139              Randall Cobb
# 163          45094              Johnny Mundt
# 164          41282             Davante Adams
# 165          52430          Justin Jefferson
#
#                                        playDescription  quarter  down  \
# 0    (11:34) (No Huddle, Shotgun) J.Burrow pass sho...        1     1
# 1    (14:19) J.Garoppolo pass short left to D.Samue...        1     2
# 2    (6:15) (Shotgun) P.Mahomes pass short middle t...        2     1
# 3    (15:00) (Shotgun) M.Trubisky pass short middle...        1     1
# 4    (14:11) (Shotgun) M.Stafford pass short right ...        2     1
# ..                                                 ...      ...   ...
# 161  (9:11) (Shotgun) J.Flacco pass short left to B...        1     2
# 162  (4:03) (Shotgun) A.Rodgers pass short left to ...        1     3
# 163  (14:54) K.Cousins pass short left to J.Mundt p...        1     1
# 164  (9:03) (Shotgun) D.Carr pass short right to D....        1     1
# 165  (11:35) (Shotgun) K.Cousins pass short right t...        1     2
#
#      yardsToGo possessionTeam defensiveTeam passResult  expectedPoints  \
# 0           10            CIN           PIT          C        2.435449
# 1            8             SF           DEN          C       -0.329895
# 2           10             KC            LV          C        4.292064
# 3           10            PIT           CIN          C        1.298699
# 4           10             LA           ATL          C        2.771719
# ..         ...            ...           ...        ...             ...
# 161         12            NYJ           BAL          C       -0.630774
# 162          4             GB           MIN          C        1.548537
# 163         10            MIN            GB          C        0.906152
# 164         10             LV           LAC          C        1.381075
# 165          5            MIN            GB          C        3.572353
#
#      expectedPointsAdded  pff_missedTackle  onDefense role_label  tackle  \
# 0              -0.338776               0.0       True    Defense     0.0
# 1               1.663811               NaN       True    Defense     NaN
# 2               0.859268               NaN       True    Defense     NaN
# 3              -0.472126               NaN       True    Defense     NaN
# 4               0.152558               0.0       True    Defense     0.0
# ..                   ...               ...        ...        ...     ...
# 161            -0.199966               NaN       True    Defense     NaN
# 162             1.566405               NaN       True    Defense     NaN
# 163             0.794783               NaN       True    Defense     NaN
# 164             0.730491               NaN       True    Defense     NaN
# 165             1.524514               NaN       True    Defense     NaN
#
#      assist  forcedFumble  pff_missedTackle  repulse_x  repulse_y  \
# 0       1.0           0.0               0.0   0.068416   0.047183
# 1       NaN           NaN               NaN   0.013806  -0.026435
# 2       NaN           NaN               NaN   0.000208  -0.027095
# 3       NaN           NaN               NaN   0.012707   0.027307
# 4       1.0           0.0               0.0   0.012365   0.064490
# ..      ...           ...               ...        ...        ...
# 161     NaN           NaN               NaN   0.005194  -0.001192
# 162     NaN           NaN               NaN   0.022233  -0.005440
# 163     NaN           NaN               NaN   0.230275   0.195094
# 164     NaN           NaN               NaN   0.001027  -0.024961
# 165     NaN           NaN               NaN   0.001676  -0.007917
#
#      repulse_total  indiv_F_theta  repulse_y_x_ratio  ballc_f_x_total  \
# 0         0.083108       0.603749           0.689655         0.050189
# 1         0.029823      -1.089489          -1.914706         0.111103
# 2         0.027096      -1.563104        -129.999998        -0.001400
# 3         0.030119       1.135254           2.148936         0.752586
# 4         0.065664       1.381366           5.215687         0.592860
# ..             ...            ...                ...              ...
# 161       0.005329      -0.225601          -0.229508         0.315017
# 162       0.022889      -0.239966          -0.244681         0.764444
# 163       0.301808       0.702879           0.847222         0.161010
# 164       0.024982      -1.529694         -24.315789         0.241652
# 165       0.008093      -1.362197          -4.724138        -0.089676
#
#      ballc_f_y_total  ballc_total_F_theta  ballc_total_F_ratio  num_tackles  \
# 0          -0.156302            -1.260095            -3.114281           67
# 1          -0.128589            -0.858220            -1.157382           35
# 2          -0.292083            -1.575589           208.649746           20
# 3           0.898658             0.873630             1.194093           57
# 4           0.441987             0.640625             0.745516           27
# ..               ...                  ...                  ...          ...
# 161        -0.129071            -0.388865            -0.409729            4
# 162        -0.760908            -0.783080            -0.995374           15
# 163         0.437870             1.218430             2.719518           24
# 164        -0.174782            -0.626178            -0.723278            4
# 165        -0.107036            -2.268171             1.193588            4
#
#      total_plays  overal_tackle_pct  player_avg    player_sum
# 0            340           0.197059    3.947524  16824.347839
# 1            164           0.213415    3.898201   6892.019089
# 2             93           0.215054    3.796134   3879.649197
# 3            274           0.208029    3.706324   7534.956308
# 4            127           0.212598    3.459788   8061.305955
# ..           ...                ...         ...           ...
# 161          111           0.036036    0.051426    125.634451
# 162          270           0.055556    0.043011    182.195084
# 163          269           0.089219    0.037081    105.197914
# 164           76           0.052632    0.025856     30.277271
# 165           65           0.061538    0.021270     14.165792
#
# [166 rows x 45 columns]

# %%
#Defensive Back Rankings
force_data_rel_completion_agg.query('total_plays >= 50').query('position == "CB" | position == "DB"').drop_duplicates('nflId').sort_values('player_avg', ascending = False).reset_index(drop = True)
# Out:
#        nflId  level_1      gameId  playId  frameId        displayName  \
# 0    41483.0  3524645  2022092507     501        1  Terrance Mitchell
# 1    54622.0  6543433  2022100908    3537        1      Zyon McCollum
# 2    54500.0   835713  2022091108     318        1     Roger McCreary
# 3    54606.0   827861  2022091107    3811        1  Damarion Williams
# 4    46775.0  1411412  2022091500     118        1       J.C. Jackson
# ..       ...      ...         ...     ...      ...                ...
# 132  42393.0  1324925  2022091200     109        1       Ronald Darby
# 133  52438.0  6369017  2022100907     295        1   Noah Igbinoghene
# 134  46215.0   427249  2022091103    2569        1        Tre Flowers
# 135  52458.0   268434  2022091102     189        1     Jaylon Johnson
# 136  41240.0   755820  2022091107     412        1        Kyle Fuller
#
#     position  last_frame                        time  jerseyNumber club  \
# 0         CB          19  2022-09-25 13:19:43.200000          39.0  TEN
# 1         CB          31  2022-10-09 15:43:13.299999          27.0   TB
# 2         CB          28  2022-09-11 16:39:34.700000          21.0  TEN
# 3         CB          35  2022-09-11 15:54:07.200000          22.0  BAL
# 4         CB          42  2022-09-15 20:18:16.099999          27.0  LAC
# ..       ...         ...                         ...           ...  ...
# 132       CB          25  2022-09-12 20:17:33.799999          23.0  DEN
# 133       CB          23  2022-10-09 13:14:07.000000           9.0  MIA
# 134       CB          25  2022-09-11 15:07:01.400000          33.0  CIN
# 135       CB          48  2022-09-11 13:08:54.000000          33.0  CHI
# 136       CB          20  2022-09-11 13:20:37.299999          23.0  BAL
#
#      season  week  ballCarrierId ballCarrierDisplayName  \
# 0      2022     3          47807            Josh Jacobs
# 1      2022     5          48723           Parker Hesse
# 2      2022     1          46071         Saquon Barkley
# 3      2022     1          54501            Breece Hall
# 4      2022     2          52440  Clyde Edwards-Helaire
# ..      ...   ...            ...                    ...
# 132    2022     1          42412          Tyler Lockett
# 133    2022     5          46279        Braxton Berrios
# 134    2022     1          47924            Zach Gentry
# 135    2022     1          47819           Deebo Samuel
# 136    2022     1          54501            Breece Hall
#
#                                        playDescription  quarter  down  \
# 0    (5:53) (Shotgun) D.Carr pass short left to J.J...        1     2
# 1    (7:52) (Shotgun) M.Mariota pass short middle t...        4     1
# 2    (9:44) (Shotgun) D.Jones pass short left to S....        1     2
# 3    (2:37) (Shotgun) J.Flacco pass short right to ...        4     2
# 4    (13:20) (Shotgun) P.Mahomes pass short left to...        1     1
# ..                                                 ...      ...   ...
# 132  (13:38) (Shotgun) G.Smith pass short middle to...        1     3
# 133  (11:14) (Shotgun) Z.Wilson pass short left to ...        1     2
# 134  (1:00) (Shotgun) M.Trubisky pass short middle ...        3     3
# 135  (12:33) (Shotgun) T.Lance pass short middle to...        1     2
# 136  (9:11) (Shotgun) J.Flacco pass short left to B...        1     2
#
#      yardsToGo possessionTeam defensiveTeam passResult  expectedPoints  \
# 0           14             LV           TEN          C        2.566176
# 1           10            ATL            TB          C        2.360609
# 2           10            NYG           TEN          C        0.786975
# 3           10            NYJ           BAL          C        2.454007
# 4           10             KC           LAC          C        2.368279
# ..         ...            ...           ...        ...             ...
# 132          3            SEA           DEN          C        0.950914
# 133          9            NYJ           MIA          C        2.968859
# 134         16            PIT           CIN          C       -0.629734
# 135          8             SF           CHI          C        2.270418
# 136         12            NYJ           BAL          C       -0.630774
#
#      expectedPointsAdded  pff_missedTackle  onDefense role_label  tackle  \
# 0              -1.315406               NaN       True    Defense     NaN
# 1               0.981955               NaN       True    Defense     NaN
# 2              -0.370533               NaN       True    Defense     NaN
# 3               1.335166               NaN       True    Defense     NaN
# 4               0.654809               NaN       True    Defense     NaN
# ..                   ...               ...        ...        ...     ...
# 132             2.206573               NaN       True    Defense     NaN
# 133            -0.885419               NaN       True    Defense     NaN
# 134            -0.366711               NaN       True    Defense     NaN
# 135            -0.130476               NaN       True    Defense     NaN
# 136            -0.199966               NaN       True    Defense     NaN
#
#      assist  forcedFumble  pff_missedTackle  repulse_x  repulse_y  \
# 0       NaN           NaN               NaN   0.000290   0.011271
# 1       NaN           NaN               NaN  -0.005439  -0.004167
# 2       NaN           NaN               NaN  -0.001779   0.003622
# 3       NaN           NaN               NaN   0.023932  -0.015964
# 4       NaN           NaN               NaN  -0.041102   0.028365
# ..      ...           ...               ...        ...        ...
# 132     NaN           NaN               NaN   0.003176  -0.015796
# 133     NaN           NaN               NaN  -0.002387   0.011982
# 134     NaN           NaN               NaN  -0.002008  -0.010127
# 135     NaN           NaN               NaN  -0.029872  -0.108626
# 136     NaN           NaN               NaN  -0.010475  -0.008766
#
#      repulse_total  indiv_F_theta  repulse_y_x_ratio  ballc_f_x_total  \
# 0         0.011274       1.545051          38.833333         0.606485
# 1         0.006852       0.653744           0.766129         0.211318
# 2         0.004035      -1.114317          -2.036364         0.210364
# 3         0.028767      -0.588268          -0.667051         0.295440
# 4         0.049940      -0.604054          -0.690104         0.016959
# ..             ...            ...                ...              ...
# 132       0.016112      -1.372370          -4.973333         0.254466
# 133       0.012218      -1.374167          -5.020000         0.334892
# 134       0.010324       1.375096           5.044445         0.217886
# 135       0.112658       1.302430           3.636364         0.131178
# 136       0.013659       0.696805           0.836842         0.315017
#
#      ballc_f_y_total  ballc_total_F_theta  ballc_total_F_ratio  num_tackles  \
# 0           0.987888             1.020204             1.628875           23
# 1           0.330396             1.001774             1.563502           10
# 2           0.149906             0.619136             0.712605           50
# 3          -0.387892            -0.919877            -1.312929           20
# 4           0.653804             1.544863            38.551112           14
# ..               ...                  ...                  ...          ...
# 132        -0.107531            -0.399813            -0.422573           14
# 133         0.249864             0.641003             0.746103            9
# 134        -0.443228            -1.113900            -2.034221           13
# 135        -1.840713            -1.499652           -14.032137           14
# 136        -0.129071            -0.388865            -0.409729            3
#
#      total_plays  overal_tackle_pct  player_avg    player_sum
# 0            137           0.167883    4.470590  10930.593075
# 1            108           0.092593    3.734241   4932.932870
# 2            366           0.136612    3.585570  20552.486337
# 3            129           0.155039    2.612328   6494.247529
# 4            167           0.083832    2.397866   5553.458002
# ..           ...                ...         ...           ...
# 132          190           0.073684    0.378753    882.493476
# 133          129           0.069767    0.353022    673.566834
# 134           63           0.206349    0.332853    410.741010
# 135          256           0.054688    0.287685    820.765920
# 136           51           0.058824    0.264636    267.547015
#
# [137 rows x 45 columns]

# %%
force_data_rel_completion_agg
# Out:
#             nflId  level_1      gameId  playId  frameId      displayName  \
# 73810     33131.0   763194  2022091107     868        1  Calais Campbell
# 73811     33131.0   763195  2022091107     868        2  Calais Campbell
# 73812     33131.0   763196  2022091107     868        3  Calais Campbell
# 73813     33131.0   763197  2022091107     868        4  Calais Campbell
# 73814     33131.0   763198  2022091107     868        5  Calais Campbell
# ...           ...      ...         ...     ...      ...              ...
# 11656826  55241.0  2657378  2022091900    3024       28      C.J. Brewer
# 11656827  55241.0  2657379  2022091900    3024       29      C.J. Brewer
# 11656828  55241.0  2657380  2022091900    3024       30      C.J. Brewer
# 11656829  55241.0  2657381  2022091900    3024       31      C.J. Brewer
# 11656830  55241.0  2657382  2022091900    3024       32      C.J. Brewer
#
#          position  last_frame                        time  jerseyNumber club  \
# 73810          DE          54  2022-09-11 13:42:32.900000          93.0  BAL
# 73811          DE          54  2022-09-11 13:42:33.000000          93.0  BAL
# 73812          DE          54  2022-09-11 13:42:33.099999          93.0  BAL
# 73813          DE          54  2022-09-11 13:42:33.200000          93.0  BAL
# 73814          DE          54  2022-09-11 13:42:33.299999          93.0  BAL
# ...           ...         ...                         ...           ...  ...
# 11656826       DT          32  2022-09-19 21:47:23.400000          98.0  BUF
# 11656827       DT          32  2022-09-19 21:47:23.500000          98.0  BUF
# 11656828       DT          32  2022-09-19 21:47:23.599999          98.0  BUF
# 11656829       DT          32  2022-09-19 21:47:23.700000          98.0  BUF
# 11656830       DT          32  2022-09-19 21:47:23.799999          98.0  BUF
#
#           season  week  ballCarrierId ballCarrierDisplayName  \
# 73810       2022     1          54475         Garrett Wilson
# 73811       2022     1          54475         Garrett Wilson
# 73812       2022     1          54475         Garrett Wilson
# 73813       2022     1          54475         Garrett Wilson
# 73814       2022     1          54475         Garrett Wilson
# ...          ...   ...            ...                    ...
# 11656826    2022     2          43334          Derrick Henry
# 11656827    2022     2          43334          Derrick Henry
# 11656828    2022     2          43334          Derrick Henry
# 11656829    2022     2          43334          Derrick Henry
# 11656830    2022     2          43334          Derrick Henry
#
#                                             playDescription  quarter  down  \
# 73810     (3:07) (Shotgun) J.Flacco pass short right to ...        1     3
# 73811     (3:07) (Shotgun) J.Flacco pass short right to ...        1     3
# 73812     (3:07) (Shotgun) J.Flacco pass short right to ...        1     3
# 73813     (3:07) (Shotgun) J.Flacco pass short right to ...        1     3
# 73814     (3:07) (Shotgun) J.Flacco pass short right to ...        1     3
# ...                                                     ...      ...   ...
# 11656826  (4:24) (No Huddle, Shotgun) R.Tannehill pass s...        3     2
# 11656827  (4:24) (No Huddle, Shotgun) R.Tannehill pass s...        3     2
# 11656828  (4:24) (No Huddle, Shotgun) R.Tannehill pass s...        3     2
# 11656829  (4:24) (No Huddle, Shotgun) R.Tannehill pass s...        3     2
# 11656830  (4:24) (No Huddle, Shotgun) R.Tannehill pass s...        3     2
#
#           yardsToGo possessionTeam defensiveTeam passResult  expectedPoints  \
# 73810            10            NYJ           BAL          C        0.328657
# 73811            10            NYJ           BAL          C        0.328657
# 73812            10            NYJ           BAL          C        0.328657
# 73813            10            NYJ           BAL          C        0.328657
# 73814            10            NYJ           BAL          C        0.328657
# ...             ...            ...           ...        ...             ...
# 11656826          2            TEN           BUF          C        2.867526
# 11656827          2            TEN           BUF          C        2.867526
# 11656828          2            TEN           BUF          C        2.867526
# 11656829          2            TEN           BUF          C        2.867526
# 11656830          2            TEN           BUF          C        2.867526
#
#           expectedPointsAdded  pff_missedTackle  onDefense role_label  tackle  \
# 73810               -0.212017               0.0       True    Defense     0.0
# 73811               -0.212017               0.0       True    Defense     0.0
# 73812               -0.212017               0.0       True    Defense     0.0
# 73813               -0.212017               0.0       True    Defense     0.0
# 73814               -0.212017               0.0       True    Defense     0.0
# ...                       ...               ...        ...        ...     ...
# 11656826            -1.479203               NaN       True    Defense     NaN
# 11656827            -1.479203               NaN       True    Defense     NaN
# 11656828            -1.479203               NaN       True    Defense     NaN
# 11656829            -1.479203               NaN       True    Defense     NaN
# 11656830            -1.479203               NaN       True    Defense     NaN
#
#           assist  forcedFumble  pff_missedTackle  repulse_x  repulse_y  \
# 73810        1.0           0.0               0.0  -0.008936   0.004931
# 73811        1.0           0.0               0.0  -0.009499   0.005665
# 73812        1.0           0.0               0.0  -0.010037   0.006158
# 73813        1.0           0.0               0.0  -0.010800   0.006745
# 73814        1.0           0.0               0.0  -0.011170   0.007144
# ...          ...           ...               ...        ...        ...
# 11656826     NaN           NaN               NaN   1.398587   2.638571
# 11656827     NaN           NaN               NaN   1.155835   1.692047
# 11656828     NaN           NaN               NaN   0.952802   0.973074
# 11656829     NaN           NaN               NaN   0.752008   0.611523
# 11656830     NaN           NaN               NaN   0.595017   0.250911
#
#           repulse_total  indiv_F_theta  repulse_y_x_ratio  ballc_f_x_total  \
# 73810          0.010206      -0.504264          -0.551852        -0.037428
# 73811          0.011060      -0.537717          -0.596330        -0.029992
# 73812          0.011775      -0.550325          -0.613553        -0.022723
# 73813          0.012734      -0.558275          -0.624549        -0.011544
# 73814          0.013259      -0.568998          -0.639556         0.000139
# ...                 ...            ...                ...              ...
# 11656826       2.986319       1.083395           1.886598        15.180639
# 11656827       2.049141       0.971504           1.463917      1304.368512
# 11656828       1.361875       0.795924           1.021277        27.118875
# 11656829       0.969266       0.682730           0.813187         7.092155
# 11656830       0.645757       0.399061           0.421687         4.158732
#
#           ballc_f_y_total  ballc_total_F_theta  ballc_total_F_ratio  \
# 73810            0.072364             2.048129            -1.933395
# 73811            0.085823             1.906990            -2.861559
# 73812            0.098053             1.798517            -4.315178
# 73813            0.109775             1.675571            -9.509365
# 73814            0.121447             1.569656           876.777442
# ...                   ...                  ...                  ...
# 11656826         2.276539             0.148854             0.149963
# 11656827      -106.773290            -0.081676            -0.081858
# 11656828        -3.529338            -0.129416            -0.130143
# 11656829        -1.100895            -0.153998            -0.155227
# 11656830        -1.506107            -0.347462            -0.362155
#
#           num_tackles  total_plays  overal_tackle_pct  player_avg  player_sum
# 73810              18          237           0.075949    0.122763  474.848166
# 73811              18          237           0.075949    0.122763  474.848166
# 73812              18          237           0.075949    0.122763  474.848166
# 73813              18          237           0.075949    0.122763  474.848166
# 73814              18          237           0.075949    0.122763  474.848166
# ...               ...          ...                ...         ...         ...
# 11656826            2           15           0.133333    0.357303   37.159479
# 11656827            2           15           0.133333    0.357303   37.159479
# 11656828            2           15           0.133333    0.357303   37.159479
# 11656829            2           15           0.133333    0.357303   37.159479
# 11656830            2           15           0.133333    0.357303   37.159479
#
# [1776324 rows x 45 columns]

# %%
force_leaderboard_send_1_8 = force_data_rel_completion_agg.drop_duplicates('nflId')[['nflId','displayName','position','club','num_tackles','total_plays','repulse_total','player_avg','overal_tackle_pct','player_sum']]

# %%
force_leaderboard_send_1_8.to_csv('force_leaderboard_full_1_8_3.csv')

# %%
force_leaderboard_send_1_8
# Out:
#             nflId        displayName position club  num_tackles  total_plays  \
# 73810     33131.0    Calais Campbell       DE  BAL           18          237
# 108157    35449.0       Tyson Alualu       NT  PIT            8          128
# 113741    35452.0     Brandon Graham       DE  PHI           12          127
# 118930    35454.0  Jason Pierre-Paul       DE  BAL            6          163
# 125561    35459.0     Kareem Jackson       SS  DEN           51          384
# ...           ...                ...      ...  ...          ...          ...
# 11653077  55190.0     Sam Okuayinonu       DE  TEN            1           25
# 11654013  55200.0     Ryder Anderson       DT  NYG            1            9
# 11654527  55239.0       Prince Emili       DT  BUF            3           23
# 11655790  55240.0   Ja'Marcus Ingram       CB  BUF            3           25
# 11656679  55241.0        C.J. Brewer       DT  BUF            2           15
#
#           repulse_total  player_avg  overal_tackle_pct   player_sum
# 73810          0.010206    0.122763           0.075949   474.848166
# 108157         0.032810    0.067775           0.062500    98.816192
# 113741         0.010827    0.193552           0.094488   387.103707
# 118930         0.055153    0.302269           0.036810   752.650708
# 125561         0.117643    0.980462           0.132812  4774.847565
# ...                 ...         ...                ...          ...
# 11653077       0.037841    0.182707           0.040000    88.247347
# 11654013       0.010484    0.011793           0.111111     0.731144
# 11654527       0.049496    0.347179           0.130435    85.058944
# 11655790       0.009336    3.204448           0.120000  1220.894512
# 11656679       0.037649    0.357303           0.133333    37.159479
#
# [845 rows x 10 columns]

# %%
force_data_rel_completion_agg['overal_tackle_pct'].corr(force_data_rel_completion_agg['player_avg'])
# Out:
# 0.5161062339268756

# %%
overall_force_data_first_5 = force_data_smaller.query('week < 6 & onDefense == True').groupby('nflId').apply(func = overall_tackler_stats).reset_index()

# %%
overall_force_data_first_5_agg = agg_max_func(overall_force_data_first_5)

# %%
overall_force_data_last_4 = force_data_smaller.query('week >= 6 & onDefense == True').groupby('nflId').apply(func = overall_tackler_stats).reset_index()

# %%
overall_force_data_last_4_agg = agg_max_func(overall_force_data_last_4)

# %%
overall_force_data_first_5_agg = overall_force_data_first_5_agg.drop_duplicates('nflId')[['nflId','displayName','position','club','num_tackles','total_plays','overal_tackle_pct', 'player_avg','player_sum']]
overall_force_data_last_4_agg = overall_force_data_last_4_agg.drop_duplicates('nflId')[['nflId','displayName','position','club','num_tackles','total_plays','overal_tackle_pct', 'repulse_total', 'player_avg','player_sum']]

# %%
overall_force_data_first_5_agg
# Out:
#            nflId        displayName position club  num_tackles  total_plays  \
# 0        33131.0    Calais Campbell       DE  BAL           11          157
# 6362     35449.0       Tyson Alualu       NT  PIT            6          100
# 10720    35452.0     Brandon Graham       DE  PHI           10           87
# 14132    35454.0  Jason Pierre-Paul       DE  BAL            4           65
# 16801    35459.0     Kareem Jackson       SS  DEN           31          223
# ...          ...                ...      ...  ...          ...          ...
# 3386735  55181.0          Tre Avery       CB  TEN            3           13
# 3387283  55190.0     Sam Okuayinonu       DE  TEN            0           17
# 3387858  55239.0       Prince Emili       DT  BUF            3           23
# 3389062  55240.0   Ja'Marcus Ingram       CB  BUF            3           25
# 3389962  55241.0        C.J. Brewer       DT  BUF            2           15
#
#          overal_tackle_pct  player_avg   player_sum
# 0                 0.070064    0.454831  2893.637244
# 6362              0.060000    0.446441  1945.588006
# 10720             0.114943    0.310622  1059.843115
# 14132             0.061538    0.628864  1678.439091
# 16801             0.139013    0.573612  5212.989652
# ...                    ...         ...          ...
# 3386735           0.230769    1.038776   569.249046
# 3387283           0.000000    0.267041   153.548580
# 3387858           0.130435    0.333373   401.380881
# 3389062           0.120000    1.955130  1759.616715
# 3389962           0.133333    0.273964   206.842897
#
# [786 rows x 9 columns]

# %%
overall_force_data_last_4_agg
# Out:
#            nflId        displayName position club  num_tackles  total_plays  \
# 0        33131.0    Calais Campbell       DE  BAL            7           80
# 3033     35449.0       Tyson Alualu       NT  PIT            2           28
# 4261     35452.0     Brandon Graham       DE  PHI            2           40
# 5980     35454.0  Jason Pierre-Paul       DE  BAL            2           98
# 9999     35459.0     Kareem Jackson       SS  DEN           20          161
# ...          ...                ...      ...  ...          ...          ...
# 2434701  55173.0        Timmy Horne       DT  ATL            5           59
# 2437111  55175.0       Nate Landman      ILB  ATL            0            1
# 2437127  55181.0          Tre Avery       CB  TEN            0            1
# 2437203  55190.0     Sam Okuayinonu       DE  TEN            1            8
# 2437522  55200.0     Ryder Anderson       DT  NYG            1            9
#
#          overal_tackle_pct  repulse_total  player_avg   player_sum
# 0                 0.087500       0.011541    0.655786  1989.000372
# 3033              0.071429       0.116794    0.353251   433.792650
# 4261              0.050000       0.000000    0.186586   320.740850
# 5980              0.020408       0.012642    0.242116   973.062268
# 9999              0.124224       0.001293    0.676690  4581.869385
# ...                    ...            ...         ...          ...
# 2434701           0.084746       0.018798    0.858292  2068.483265
# 2437111           0.000000       0.082889    0.050353     0.805641
# 2437127           0.000000       0.007733    0.063052     4.791962
# 2437203           0.125000       0.000000    0.352904   112.576497
# 2437522           0.111111       0.114072    0.368668   158.527148
#
# [739 rows x 10 columns]

# %%
overall_force_data_first_5_agg = overall_force_data_first_5_agg.rename(columns = {'total_plays': 'total_plays_first','overal_tackle_pct': 'overall_tackle_pct_first', 'player_avg': 'player_avg_first','player_sum': 'player_sum_first'})

# %%
overall_force_data_last_4_agg = overall_force_data_last_4_agg.rename(columns = {'total_plays': 'total_plays_second','overal_tackle_pct': 'overall_tackle_pct_second', 'player_avg': 'player_avg_second','player_sum': 'player_sum_second'})

# %%
merged_data = pd.merge(overall_force_data_first_5_agg, overall_force_data_last_4_agg, on='nflId', how='inner')

# %%
merged_data
# Out:
#        nflId      displayName_x position_x club_x  num_tackles_x  \
# 0    33131.0    Calais Campbell         DE    BAL             11
# 1    35449.0       Tyson Alualu         NT    PIT              6
# 2    35452.0     Brandon Graham         DE    PHI             10
# 3    35454.0  Jason Pierre-Paul         DE    BAL              4
# 4    35459.0     Kareem Jackson         SS    DEN             31
# ..       ...                ...        ...    ...            ...
# 658  55149.0     Markquese Bell         FS    DAL              1
# 659  55173.0        Timmy Horne         DT    ATL              4
# 660  55175.0       Nate Landman        ILB    ATL              1
# 661  55181.0          Tre Avery         CB    TEN              3
# 662  55190.0     Sam Okuayinonu         DE    TEN              0
#
#      total_plays_first  overall_tackle_pct_first  player_avg_first  \
# 0                  157                  0.070064          0.454831
# 1                  100                  0.060000          0.446441
# 2                   87                  0.114943          0.310622
# 3                   65                  0.061538          0.628864
# 4                  223                  0.139013          0.573612
# ..                 ...                       ...               ...
# 658                  1                  1.000000          1.586881
# 659                 70                  0.057143          0.758380
# 660                  8                  0.125000          0.620293
# 661                 13                  0.230769          1.038776
# 662                 17                  0.000000          0.267041
#
#      player_sum_first      displayName_y position_y club_y  num_tackles_y  \
# 0         2893.637244    Calais Campbell         DE    BAL              7
# 1         1945.588006       Tyson Alualu         NT    PIT              2
# 2         1059.843115     Brandon Graham         DE    PHI              2
# 3         1678.439091  Jason Pierre-Paul         DE    BAL              2
# 4         5212.989652     Kareem Jackson         SS    DEN             20
# ..                ...                ...        ...    ...            ...
# 658         76.170303     Markquese Bell         FS    DAL              0
# 659       2222.811719        Timmy Horne         DT    ATL              5
# 660        142.047070       Nate Landman        ILB    ATL              0
# 661        569.249046          Tre Avery         CB    TEN              0
# 662        153.548580     Sam Okuayinonu         DE    TEN              1
#
#      total_plays_second  overall_tackle_pct_second  repulse_total  \
# 0                    80                   0.087500       0.011541
# 1                    28                   0.071429       0.116794
# 2                    40                   0.050000       0.000000
# 3                    98                   0.020408       0.012642
# 4                   161                   0.124224       0.001293
# ..                  ...                        ...            ...
# 658                   8                   0.000000       0.078186
# 659                  59                   0.084746       0.018798
# 660                   1                   0.000000       0.082889
# 661                   1                   0.000000       0.007733
# 662                   8                   0.125000       0.000000
#
#      player_avg_second  player_sum_second
# 0             0.655786        1989.000372
# 1             0.353251         433.792650
# 2             0.186586         320.740850
# 3             0.242116         973.062268
# 4             0.676690        4581.869385
# ..                 ...                ...
# 658           0.175259          66.948860
# 659           0.858292        2068.483265
# 660           0.050353           0.805641
# 661           0.063052           4.791962
# 662           0.352904         112.576497
#
# [663 rows x 18 columns]

# %%
data_halves_corr = merged_data[['nflId','displayName_x','position_x','club_x','total_plays_first','overall_tackle_pct_first','player_avg_first','player_sum_first','total_plays_second','overall_tackle_pct_second','player_avg_second','player_sum_second']]

# %%
merged_data_filter = merged_data.query('total_plays_first >= 30 & total_plays_second >= 30')

# %%
merged_data_filter['player_avg_first'].corr(merged_data_filter['player_avg_second'])
# Out:
# 0.2900456982241231

# %%
print('test')

# %%
data_halves_corr.query('total_plays_first >= 30 & total_plays_second >= 30')['player_avg_first'].corr(data_halves_corr.query('total_plays_first >= 30 & total_plays_second >= 30')['player_avg_second'])
# Out:
# 0.2900456982241231

# %%
data_halves_corr.to_csv('data_halves_corr.csv')

# %%
data_halves_corr.player_avg_first.isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 658    False
# 659    False
# 660    False
# 661    False
# 662    False
# Name: player_avg_first, Length: 663, dtype: bool

# %%
data_halves_corr
# Out:
#        nflId      displayName_x position_x club_x  total_plays_first  \
# 0    33131.0    Calais Campbell         DE    BAL                157
# 1    35449.0       Tyson Alualu         NT    PIT                100
# 2    35452.0     Brandon Graham         DE    PHI                 87
# 3    35454.0  Jason Pierre-Paul         DE    BAL                 65
# 4    35459.0     Kareem Jackson         SS    DEN                223
# ..       ...                ...        ...    ...                ...
# 658  55149.0     Markquese Bell         FS    DAL                  1
# 659  55173.0        Timmy Horne         DT    ATL                 70
# 660  55175.0       Nate Landman        ILB    ATL                  8
# 661  55181.0          Tre Avery         CB    TEN                 13
# 662  55190.0     Sam Okuayinonu         DE    TEN                 17
#
#      overall_tackle_pct_first  player_avg_first  player_sum_first  \
# 0                    0.070064          0.454831       2893.637244
# 1                    0.060000          0.446441       1945.588006
# 2                    0.114943          0.310622       1059.843115
# 3                    0.061538          0.628864       1678.439091
# 4                    0.139013          0.573612       5212.989652
# ..                        ...               ...               ...
# 658                  1.000000          1.586881         76.170303
# 659                  0.057143          0.758380       2222.811719
# 660                  0.125000          0.620293        142.047070
# 661                  0.230769          1.038776        569.249046
# 662                  0.000000          0.267041        153.548580
#
#      total_plays_second  overall_tackle_pct_second  player_avg_second  \
# 0                    80                   0.087500           0.655786
# 1                    28                   0.071429           0.353251
# 2                    40                   0.050000           0.186586
# 3                    98                   0.020408           0.242116
# 4                   161                   0.124224           0.676690
# ..                  ...                        ...                ...
# 658                   8                   0.000000           0.175259
# 659                  59                   0.084746           0.858292
# 660                   1                   0.000000           0.050353
# 661                   1                   0.000000           0.063052
# 662                   8                   0.125000           0.352904
#
#      player_sum_second
# 0          1989.000372
# 1           433.792650
# 2           320.740850
# 3           973.062268
# 4          4581.869385
# ..                 ...
# 658          66.948860
# 659        2068.483265
# 660           0.805641
# 661           4.791962
# 662         112.576497
#
# [663 rows x 12 columns]
